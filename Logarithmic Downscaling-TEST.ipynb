# %% [markdown]
# # Different Downscaling Methods in Machine Learning

# %% [markdown]
# ## 1) Logarithmic Downscaling

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import ticker

# %%
x = [8056, 94561,32187,12687891,2,664,1237,1,3,4578,218987,12387891231,74484123,7894235488945321]
y = [10,122,385,144,205,456,500,1,39,100,191,262,413,314]

# %%
logarithm = []
print("By default log to the base 'e' is considered and the value of 'e' -> 2.718281828…\n")
print("Original Values ","|     Log Reduced Values")
print("")

for i in x:
    g = math.log(i)
    print("  ", i, "         |      ", g)
    logarithm.append(g)
# Out:
# By default log to the base 'e' is considered and the value of 'e' -> 2.718281828…
#
# Original Values  |     Log Reduced Values
#
#    8056          |       8.994172434398399
#    94561          |       11.457000407880116
#    32187          |       10.379317923304855
#    12687891          |       16.356158632025412
#    2          |       0.6931471805599453
#    664          |       6.498282149476434
#    1237          |       7.1204443723924875
#    1          |       0.0
#    3          |       1.0986122886681098
#    4578          |       8.429017500512511
#    218987          |       12.296767646306126
#    12387891231          |       23.239985318828314
#    74484123          |       18.126096546543792
#    7894235488945321          |       36.60490920309039

# %%
sns.barplot(x = y, y = x)
plt.title('Graph of Original Values')
plt.xlabel('Original Values')
plt.show()
print("The above Graph itself shows us that, the last value at 14 is soo large in magnitude that the other values aren't even comparable and that's exacty what we're solving using Logarithm.")

print("\n-----------------------------------------------------------------------------------------------------\n")

print("THe below Graph shows, us how the Values have been downscaled, so that all the values are visually comparable.")
sns.barplot(y = logarithm, x = y)
plt.title('Graph of Logarithm Values')
plt.xlabel('Logarithm Values')
plt.show()
plt.show()
# Out:
# The above Graph itself shows us that, the last value at 14 is soo large in magnitude that the other values aren't even comparable and that's exacty what we're solving using Logarithm.
#
# -----------------------------------------------------------------------------------------------------
#
# THe below Graph shows, us how the Values have been downscaled, so that all the values are visually comparable.

# %% [markdown]
# ***

# %% [markdown]
# ## 2) Standarization

# %%
n = len(x)
mean_ans = 0
ans = 0
j = 0

for i in x:
    j = j + i
    k = i*i;
    ans = ans + k   
    
print("n : ", n)
print("Summation (X)   : ", j)
print("Summation (X^2) : ", ans)

mean = j/n

part_1 = ans/n
part_2 = mean*mean
standard_deviation = part_1 - part_2

print ("\nStandard Deviation : {:.5f}".format(standard_deviation))

print("Mean               : ", mean)

print("\n\n")

final_z_score = []

for i in x:
    z_score = (i-mean)/standard_deviation
    final_z_score.append("{:.32f}".format(z_score))


print("Y  |   Original DataSet   |               Z-Score ")
print()
for i in range (len(x)):
    print(y[i], " |  ", x[i], "              |     ", final_z_score[i])
    
    
print("\n\n\nVISUALIZATIONS")
print("The FOLLOWING GRAPHS BELOW ARE NOT VISUALLY DISPLAYED PROPERLY, PLEASE CHECK THE NEXT CELL FOR BETTER GRAPH VISUALIZATIONS")

sns.barplot(y = x, x = y)
#plt.xticks(rotation=75)
plt.title('Graph of Original Values')
plt.xlabel('Original Values')
plt.show()

print("The above graph is of the Out of Scale Visually Incomparable Values.")

print("\n----------------------------------------------------------------------------------------------------\n")

print("The below Graph is the Standardized Scaled Down Values which are comparable.")
print("Just like we read, understood and illustrated the Standardized Values are those, which downscales all the Features to a scale common to all the Feature Values.")
sns.barplot(y = final_z_score, x = y)
sns.set(rc={'figure.figsize':(10,10)})
plt.title('Graph of Standardized Values')
plt.xlabel('Standardized Values')
plt.show()

print("\n---------------------------------------------------------------------------------------------------\n")

print("The below Graph is the vertically aligned Graph to compare with the Original Values Graph")
sns.barplot(x = final_z_score, y = y)
plt.xticks(rotation=90)
plt.title('Graph of Standardized Values')
plt.xlabel('Standardized Values')
plt.show()
# Out:
# n :  14
# Summation (X)   :  7894247964368842
# Summation (X^2) :  62318953955077236874473192515570
#
# Standard Deviation : 4133399002286426938251036065792.00000
# Mean               :  563874854597774.4
#
#
#
# Y  |   Original DataSet   |               Z-Score
#
# 10  |   8056               |      -0.00000000000000013641916840784204
# 122  |   94561               |      -0.00000000000000013641916838691376
# 385  |   32187               |      -0.00000000000000013641916840200400
# 144  |   12687891               |      -0.00000000000000013641916534018878
# 205  |   2               |      -0.00000000000000013641916840979055
# 456  |   664               |      -0.00000000000000013641916840963041
# 500  |   1237               |      -0.00000000000000013641916840949177
# 1  |   1               |      -0.00000000000000013641916840979080
# 39  |   3               |      -0.00000000000000013641916840979033
# 100  |   4578               |      -0.00000000000000013641916840868349
# ...

# %% [markdown]
# ***

# %%
fig = plt.figure()
fig.set_figwidth(8)
fig.set_figheight(6)
ax = fig.add_axes([0,0,1,1])

plt.title('Graph of Original Values')
plt.xlabel('Original Y Values')
plt.ylabel('Original X Values')
ax.bar(y, x, 15)
plt.xticks(y)
plt.show()

print("The above graph is of the Out of Scale Visually Incomparable Values.")

print("\n----------------------------------------------------------------------------------------------------\n")

print("The below Graph is the Standardized Scaled Down Values which are comparable.")
print("Just like we read, understood and illustrated, the Standardized Values are those which downscales all the Features to a scale common to all the Feature Values.")

fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(7)
ax = fig.add_axes([0,0,1,1])

plt.rc('axes', titlesize = 25) 
#plt.rc('axes', labelsize = 20)
#plt.rc('xtick', labelsize = 10) 
#plt.rc('ytick', labelsize = 15) 
plt.title('Graph of Standardized Values')
plt.xlabel('Original Y Values')
plt.ylabel('Standardized Values')
ax.bar(y, final_z_score, 15)
plt.xticks(y)
plt.show()
# Out:
# The above graph is of the Out of Scale Visually Incomparable Values.
#
# ----------------------------------------------------------------------------------------------------
#
# The below Graph is the Standardized Scaled Down Values which are comparable.
# Just like we read, understood and illustrated, the Standardized Values are those which downscales all the Features to a scale common to all the Feature Values.

# %% [markdown]
# ## 3) Normalization

# %%
min_dataset_1 = min(x)
max_dataset_1 = max(x)

print("Min(dataset_1) : ", min_dataset_1 )
print("Max(dataset_1) : ", max_dataset_1 )



final_normalization = []

print("\nNormalization = (Current_Value - Min) / (Max - Min)\n")

for i in x:
    normalization = (i - min_dataset_1) / (max_dataset_1 - min_dataset_1 )
    final_normalization.append("{:.20f}".format(normalization))
    
    
print(" Y   |  Original DataSet   |         Normalization ")
print()
for i in range (len(x)):
    print(y[i], " |  ", x[i], "            |     ", final_normalization[i])
    
    
print("\n\n")
    
fig, ax = plt.subplots()
    
ax = sns.barplot(y = x, x = y)
plt.title('Graph of Original Values')
plt.xlabel('Original Values')
plt.show()

print("The above graph is of the Out of Scale Visually Incomparable Values.")

print("\n----------------------------------------------------------------------------------------------------\n")

print("The below Graph is the Normalized Scaled Down Values which are comparable.")
print("Just like we read, understood and illustrated with example, the Normalized Values also are scaled down but here it's in a range from 0 - 1.")
sns.barplot(x = y, y = final_normalization)
plt.title('Graph of Normalized Values')
plt.xlabel('Normalized Values')
plt.show()

print("\n---------------------------------------------------------------------------------------------------\n")

print("The below Graph is the same as the 2nd Graph but just vertically aligned to compare with the Original Values Graph")

sns.barplot(x = final_normalization, y = y, ax = ax)
ax.tick_params(axis="x", rotation=90)
plt.title('Graph of Normalized Values')
plt.xlabel('Normalized Values')
plt.show()
# Out:
# Min(dataset_1) :  1
# Max(dataset_1) :  7894235488945321
#
# Normalization = (Current_Value - Min) / (Max - Min)
#
#  Y   |  Original DataSet   |         Normalization
#
# 10  |   8056             |      0.00000000000102036480
# 122  |   94561             |      0.00000000001197836068
# 385  |   32187             |      0.00000000000407715225
# 144  |   12687891             |      0.00000000160723480035
# 205  |   2             |      0.00000000000000012667
# 456  |   664             |      0.00000000000008398533
# 500  |   1237             |      0.00000000000015656994
# 1  |   1             |      0.00000000000000000000
# 39  |   3             |      0.00000000000000025335
# 100  |   4578             |      0.00000000000057979015
# 191  |   218987             |      0.00000000002773998829
# 262  |   12387891231             |      0.00000156923254282791
# 413  |   74484123             |      0.00000000943525463667
# ...

# %%
fig = plt.figure()
fig.set_figwidth(8)
fig.set_figheight(6)
ax = fig.add_axes([0,0,1,1])

plt.title('Graph of Original Values')
plt.xlabel('Original Y Values')
plt.ylabel('Original X Values')
ax.bar(y, x, 15)
plt.xticks(y)
plt.show()

print("The above graph is of the Out of Scale Visually Incomparable Values.")

print("\n----------------------------------------------------------------------------------------------------\n")

print("The below Graph is the Normalized Scaled Down Values which are comparable.")
print("Just like we read, understood and illustrated, the Normalized Values are those which downscales all the Features within a range always between 0 - 1.")

fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(7)
ax = fig.add_axes([0,0,1,1])

plt.rc('axes', titlesize = 25) 
#plt.rc('axes', labelsize = 20)
#plt.rc('xtick', labelsize = 10) 
#plt.rc('ytick', labelsize = 15) 
plt.title('Graph of Normalized Values')
plt.xlabel('Original Y Values')
plt.ylabel('Normalized Values')
ax.bar(y, final_normalization, 15)
plt.xticks(y)
plt.show()
# Out:
# The above graph is of the Out of Scale Visually Incomparable Values.
#
# ----------------------------------------------------------------------------------------------------
#
# The below Graph is the Normalized Scaled Down Values which are comparable.
# Just like we read, understood and illustrated, the Normalized Values are those which downscales all the Features within a range always between 0 - 1.

# %% [markdown]
# ***

# %% [markdown]
# ## Comparing all the Column Graphs

# %%
logarithm
# Out:
# [8.994172434398399,
#  11.457000407880116,
#  10.379317923304855,
#  16.356158632025412,
#  0.6931471805599453,
#  6.498282149476434,
#  7.1204443723924875,
#  0.0,
#  1.0986122886681098,
#  8.429017500512511,
#  12.296767646306126,
#  23.239985318828314,
#  18.126096546543792,
#  36.60490920309039]

# %%
sns.barplot(y = logarithm, x = y)
plt.title('Graph of Logarithm Values')
plt.xlabel('Logarithm Values')
plt.show()
plt.show()



fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(8)
ax = fig.add_axes([0,0,1,1])

plt.title('Graph of Original Values')
plt.xlabel('Standardized Values')
ax.bar(y, x, 15)
plt.xticks(y)
plt.show()

print("\n\n")

fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(8)
ax = fig.add_axes([0,0,1,1])

plt.rc('axes', titlesize = 25) 
plt.title('Graph of Original Values')
plt.xlabel('Standardized Values')
ax.bar(y, final_z_score, 15)
plt.xticks(y)
plt.show()

# %%
final_z_score
# Out:
# ['-0.00000000000000012667491129499132',
#  '-0.00000000000000012667491127555791',
#  '-0.00000000000000012667491128957027',
#  '-0.00000000000000012667490844645682',
#  '-0.00000000000000012667491129680065',
#  '-0.00000000000000012667491129665195',
#  '-0.00000000000000012667491129652322',
#  '-0.00000000000000012667491129680087',
#  '-0.00000000000000012667491129680043',
#  '-0.00000000000000012667491129577267',
#  '-0.00000000000000012667491124760551',
#  '-0.00000000000000012667212834769450',
#  '-0.00000000000000012667489456388671',
#  '0.00000000000000164677104424511311']

# %%
sns.barplot(x = final_z_score, y = y)
plt.title('Graph of Standardized Values')
plt.xlabel('Standardized Values')
plt.show()


fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(8)
ax = fig.add_axes([0,0,1,1])

plt.title('Graph of Original Values')
plt.xlabel('Standardized Values')
ax.bar(y, x, 15)
plt.xticks(y)
plt.show()

print("\n\n")

fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(8)
ax = fig.add_axes([0,0,1,1])

plt.rc('axes', titlesize = 25) 
plt.title('Graph of Original Values')
plt.xlabel('Standardized Values')
ax.bar(y, final_z_score, 15)
plt.xticks(y)
plt.show()

# %%
final_normalization
# Out:
# ['0.00000000000102036480',
#  '0.00000000001197836068',
#  '0.00000000000407715225',
#  '0.00000000160723480035',
#  '0.00000000000000012667',
#  '0.00000000000008398533',
#  '0.00000000000015656994',
#  '0.00000000000000000000',
#  '0.00000000000000025335',
#  '0.00000000000057979015',
#  '0.00000000002773998829',
#  '0.00000156923254282791',
#  '0.00000000943525463667',
#  '1.00000000000000000000']

# %%
sns.barplot(x = final_normalization, y = y)
plt.title('Graph of Normalized Values')
plt.xlabel('Normalized Values')
plt.show()



fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(8)
ax = fig.add_axes([0,0,1,1])

plt.title('Graph of Original Values')
plt.xlabel('Standardized Values')
ax.bar(y, x, 15)
plt.xticks(y)
plt.show()

print("\n\n")

fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(8)
ax = fig.add_axes([0,0,1,1])

plt.rc('axes', titlesize = 25) 
plt.title('Graph of Original Values')
plt.xlabel('Standardized Values')
ax.bar(y, final_z_score, 15)
plt.xticks(y)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## Thank you all for Reading!

# %% [markdown]
# ***
